# %% [markdown]
# <a href="https://colab.research.google.com/github/hussain-azmat/hussain-azmat/blob/main/Assignment2OLS_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
def msee(actual, predicted):
    sum_error = 0.0
    for i in range(len(actual)):
        prediction_error = predicted[i] - actual[i]
        sum_error += (prediction_error ** 2)
        mean_error = sum_error / float(len(actual))
    return mean_error

# %%
def Train(X,Y):
    ''' With this function we are calculate the weights   '''
    X.astype(float)
    first=np.dot(X.T,X)
    first.astype(np.float16)
    inverse=np.linalg.inv(first)
    second=np.dot(X.T,Y)

    b=np.dot(inverse,second)
    return b

# %%
def add_bias(x):
    if (len(x.shape)==1):
        x=x[:,np.newaxis]
    b=np.ones((x.shape[0],1))
    x=np.concatenate((b,x), axis=1)
    return x

# %%
def predict(X,b):
    return (np.dot(X,b))

# %%
df=pd.read_csv('MpgData_with_Cateogeries.csv')
col=df.columns
we=df.to_numpy()
we=we[:,0:8]
we=we.astype(np.float64)
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  15.0          8         350.0       165.0  3693.0          11.5
# 1  18.0          8         318.0       150.0  3436.0          11.0
# 2  16.0          8         304.0       150.0  3433.0          12.0
# 3  17.0          8         302.0       140.0  3449.0          10.5
# 4  15.0          8         429.0       198.0  4341.0          10.0
#
#    model year  origin category             carname
# 0          70       1      low   buick skylark 320
# 1          70       1   Medium  plymouth satellite
# 2          70       1      low       amc rebel sst
# 3          70       1      low         ford torino
# 4          70       1      low    ford galaxie 500

# %%
xtrain=we[:292,1:8]
ytrain=we[:292,0]
xtest=we[292:,1:8]
ytest=we[292:,0]

# %%
for i in range(2,8):
    x_train=add_bias(xtrain[:,0:i])
    b=Train(x_train,ytrain)
    train_predict=predict(x_train,b)
    train_error=msee(ytrain,train_predict)
    print('Training  Error for Multivariable regression using  {} variables is   {}  '.format(i,train_error))
# Out:
# Training  Error for Multivariable regression using  2 variables is   10.83358154512922
# Training  Error for Multivariable regression using  3 variables is   10.476388388884441
# Training  Error for Multivariable regression using  4 variables is   8.132889689912501
# Training  Error for Multivariable regression using  5 variables is   8.101001431734586
# Training  Error for Multivariable regression using  6 variables is   7.056627385554312
# Training  Error for Multivariable regression using  7 variables is   6.782307383282699
# <ipython-input-2-76aea0db308e>:5: RuntimeWarning: overflow encountered in cast
#   first.astype(np.float16)

# %%
for i in range(2,8):
    x_train=add_bias(xtrain[:,0:i])
    x_test=add_bias(xtest[:,0:i])
    b=Train(x_train,ytrain)
    test_predict=predict(x_test,b)
    test_error=msee(ytest,test_predict)
    print('Testing Error for Multivariable regression using  {} variables is   {}  '.format(i,test_error))
# Out:
# Testing Error for Multivariable regression using  2 variables is   68.9594616020743
# Testing Error for Multivariable regression using  3 variables is   66.32165298763702
# Testing Error for Multivariable regression using  4 variables is   64.01097769920605
# Testing Error for Multivariable regression using  5 variables is   64.08819848174717
# Testing Error for Multivariable regression using  6 variables is   38.32210930957728
# Testing Error for Multivariable regression using  7 variables is   36.03864957568025
# <ipython-input-2-76aea0db308e>:5: RuntimeWarning: overflow encountered in cast
#   first.astype(np.float16)

# %%
x_train=add_bias(xtrain)
x_test=add_bias(xtest)
b=Train(x_train,ytrain)
test_predict=predict(x_test,b)
plt.figure(figsize=(10,5))
plt.title('Multivariate linear regression for Test data',fontsize=16)
plt.grid(True)
plt.plot(ytest , color='purple')
plt.plot(test_predict , color='red'  )
plt.legend(["Original Values", "Predicted Values"], loc ="upper right")
plt.show()
# Out:
# <ipython-input-2-76aea0db308e>:5: RuntimeWarning: overflow encountered in cast
#   first.astype(np.float16)
